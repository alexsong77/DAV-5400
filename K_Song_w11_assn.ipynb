# %% [markdown]
# # Narratives 1
# **1. Created an account in The New York Times web** <br>
# **2. Generated a API key for all of apps** <br>
# **3. Chose the article search API** <br>
# **4. Used the API key to read JSON data in python** <br>
# **5. Imported the generated url** <br>
# **6. Converted the article object's JSON content into a dict** <br>
# **7. Extracted the useful content** <br>
# **8. Converted some of the extracted JSON data into a data frame**<br>

# %%
import requests
url = 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=9nGWAPcweS0WsiTehmGFjgjtoeuwkuU8'
article = requests.get(url)
article.text
# Out:
# '{"status":"OK","copyright":"Copyright (c) 2019 The New York Times Company. All Rights Reserved.","response":{"docs":[{"web_url":"https://query.nytimes.com/gst/abstract.html?res=9A00E2DE123AE63ABC4F52DFB366838C679EDE","snippet":"WASHINGTON, May 16-- The Administration proposed to Congress today legislation intended to provide American Indians with better economic and social tools, including a $500million loan guaranty and insurance fund.","lead_paragraph":"WASHINGTON, May 16-- The Administration proposed to Congress today legislation intended to provide American Indians with better economic and social tools, including a $500million loan guaranty and insurance fund.","print_page":"30","blog":{},"source":"The New York Times","multimedia":[],"headline":{"main":"PRESIDENT URGES BROAD TRIBAL AID; Bill Proposes $500-Million Loan Fund for Indians","kicker":null,"content_kicker":null,"print_headline":null,"name":null,"seo":null,"sub":null},"keywords":[{"name":"subject","value":"INDIANS, AMER
# ...

# %%
# now convert the 'article' object's JSON content into a dict of 
# native Python objects
data = article.json()
type(data)
# Out:
# dict

# %%
# check the content of the dict
data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9A00E2DE123AE63ABC4F52DFB366838C679EDE',
#     'snippet': 'WASHINGTON, May 16-- The Administration proposed to Congress today legislation intended to provide American Indians with better economic and social tools, including a $500million loan guaranty and insurance fund.',
#     'lead_paragraph': 'WASHINGTON, May 16-- The Administration proposed to Congress today legislation intended to provide American Indians with better economic and social tools, including a $500million loan guaranty and insurance fund.',
#     'print_page': '30',
#     'blog': {},
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'PRESIDENT URGES BROAD TRIBAL AID; Bill Proposes $500-Million Loan Fund for Indians',
#      'kicker': None,
#      'content_kicker': None,
# ...

# %%
# Extracted the content started from response 
data1 = data['response']
data1
# Out:
# {'docs': [{'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9A00E2DE123AE63ABC4F52DFB366838C679EDE',
#    'snippet': 'WASHINGTON, May 16-- The Administration proposed to Congress today legislation intended to provide American Indians with better economic and social tools, including a $500million loan guaranty and insurance fund.',
#    'lead_paragraph': 'WASHINGTON, May 16-- The Administration proposed to Congress today legislation intended to provide American Indians with better economic and social tools, including a $500million loan guaranty and insurance fund.',
#    'print_page': '30',
#    'blog': {},
#    'source': 'The New York Times',
#    'multimedia': [],
#    'headline': {'main': 'PRESIDENT URGES BROAD TRIBAL AID; Bill Proposes $500-Million Loan Fund for Indians',
#     'kicker': None,
#     'content_kicker': None,
#     'print_headline': None,
#     'name': None,
#     'seo': None,
#     'sub': None},
#    'keywords': [{'name': 'subject',
# ...

# %%
# now convert some of the extracted JSON data into a data frame: in this
# we are extracting the 'web_url', 'snippet','lead_paragraph', 'print_page','pub_date','document_type','type_of_material','_id','word_count','score'
# components of the dict object
import pandas as pd 
issues = pd.DataFrame(data2, columns=['web_url', 'snippet',
                                     'lead_paragraph', 'print_page','pub_date','document_type','type_of_material',
                                     '_id','word_count','score'])
issues
# Out:
#                                              web_url  \
# 0  https://query.nytimes.com/gst/abstract.html?re...
# 1  https://query.nytimes.com/gst/abstract.html?re...
# 2  https://query.nytimes.com/gst/abstract.html?re...
# 3  https://query.nytimes.com/gst/abstract.html?re...
# 4  https://query.nytimes.com/gst/abstract.html?re...
# 5  https://query.nytimes.com/gst/abstract.html?re...
# 6  https://query.nytimes.com/gst/abstract.html?re...
# 7  https://query.nytimes.com/gst/abstract.html?re...
# 8  https://query.nytimes.com/gst/abstract.html?re...
# 9  https://query.nytimes.com/gst/abstract.html?re...
#
#                                              snippet  \
# 0  WASHINGTON, May 16-- The Administration propos...
# 1  Charlie Wohlstetter and Phil Lucier are probab...
# 2  Darryl F. Zanuck, one of the last of the great...
# 3  WASHINGTON, June 29 The Federal Reserve Board ...
# 4  4 economists hold dollar would be strengthened...
# 5  Wiretaps in which Suffolk County Judge Floyd S...
# ...

# %% [markdown]
# # Narratives 2
# **1. Created an account in The New York Times web** <br>
# **2. Generated a API key for all of apps** <br>
# **3. Chose the review API** <br>
# **4. Used the API key to read JSON data in python** <br>
# **5. Imported the generated url** <br>
# **6. Converted the article object's JSON content into a dict** <br>
# **7. Extracted the useful content** <br>
# **8. Converted some of the extracted JSON data into a data frame**<br>

# %%
import requests
url = 'https://api.nytimes.com/svc/movies/v2/critics/all.json?api-key=9nGWAPcweS0WsiTehmGFjgjtoeuwkuU8'
review = requests.get(url)
review.text
# Out:
# '{"status":"OK","copyright":"Copyright (c) 2019 The New York Times Company. All Rights Reserved.","num_results":82,"results":[{"display_name":"A. O. Scott","sort_name":"A. O. Scott","status":"full-time","bio":"A. O. Scott joined The New York Times as a film critic in January 2000, and was named a chief critic in 2004. Previously, Mr. Scott had been the lead Sunday book reviewer for Newsday and a frequent contributor to Slate, The New York Review of Books, and many other publications. \\n<br\\/><br\\/>\\nIn the 1990s he served on the editorial staffs of Lingua Franca and The New York Review of Books. He also edited \\"A Bolt from the Blue and Other Essays,\\" a collection by Mary McCarthy, which was published by The New York Review of Books in 2002. \\n<br\\/><br\\/>\\nMr. Scott was a finalist for the Pulitzer Prize in Criticism in 2010, the same year he served as co-host (with Michael Phillips of the Chicago Tribune) on the last season of \\"At the Movies,\\" the syndicated film-revi
# ...

# %%
# now convert the 'review' object's JSON content into a dict of 
# native Python objects
data = review.json()
type(data)
# Out:
# dict

# %%
# check the content of the dict
data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'num_results': 82,
#  'results': [{'display_name': 'A. O. Scott',
#    'sort_name': 'A. O. Scott',
#    'status': 'full-time',
# ...

# %%
# Extracted data started from results 
data3 = data['results']
data3
# Out:
# [{'display_name': 'A. O. Scott',
#   'sort_name': 'A. O. Scott',
#   'status': 'full-time',
# ...

# %%
# now convert some of the extracted JSON data into a data frame: in this
# we are extracting the 'display_name', 'sort_name', 'status','bio' and 'seo_name'
# components of the dict object
import pandas as pd 
reviews = pd.DataFrame(data3, columns=['display_name', 'sort_name',
                                     'status', 'bio','seo_name'
                                     ])
reviews
# Out:
#            display_name             sort_name     status  \
# 0           A. O. Scott           A. O. Scott  full-time
# 1        Manohla Dargis        Manohla Dargis  full-time
# 2        Stephen Holden        Stephen Holden  full-time
# 3          Renata Adler         Adler, Renata  part-time
# 4         Mordaunt Hall       Hall, Mordaunt   part-time
# 5       Thomas M. Pryor      Pryor, Thomas M.  part-time
# 6         Eugene Archer        Archer, Eugene  part-time
# 7      Donal J. Henahan     Henahan, Donal J.  part-time
# 8            Nora Sayre           Sayre, Nora  part-time
# 9     D. J. R. Bruckner   Bruckner, D. J. R.   part-time
# 10          Caryn James          James, Caryn  part-time
# 11  Harold C. Schonberg  Schonberg, Harold C.  part-time
# 12          Tom Buckley         Buckley, Tom   part-time
# 13     Stanley Kauffman     Kauffman, Stanley  part-time
# 14       Andre Sennwald       Sennwald, Andre  part-time
# ...
